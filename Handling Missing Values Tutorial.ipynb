# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# ## Setup working directory & read .csv file

# %%
# Import importany libraries [os, pandas, numpy]
import os
import pandas as pd
import numpy as np

# %%
# Setup your working directory
os.getcwd()
# Out:
# 'C:\\Users\\Ashish Sharma\\Documents\\Handling missing values_Tutorial'

# %%
# Read the data .csv file using pandas
student = pd.read_csv("student_data.csv")
student
# Out:
#     serial_no    Student mentor_name  maths_marks  science_marks  \
# 0           1        Ola       Sagar         70.0           73.0
# 1           2       Ruby     Phillip         74.0           77.0
# 2           3      Aimee      Vincia         87.0           90.0
# 3           4     Olivia        Mark         77.0           80.0
# 4           5       Otis       Milly         91.0           94.0
# 5           6      Maeve        Oven         78.0           81.0
# 6           7        NaN       Kevin         84.0            NaN
# 7           8       Eric      Vincia         76.0           79.0
# 8           9      Isaac        Mark         83.0           86.0
# 9          10      Rahim       Milly         84.0           87.0
# 10         11        Dan        Oven         79.0           82.0
# 11         12        NaN         NaN          NaN            NaN
# 12         13    Chandan       Milly         78.0           81.0
# 13         14   Rochelle        Oven         85.0           88.0
# 14         15  Sebastian       Kevin         95.0           98.0
# 15         16      Elvin      Vincia         72.0           75.0
# 16         17        NaN        Mark          NaN            NaN
# 17         18        Rob       Milly         74.0           77.0
# 18         19     Fiefen         NaN         78.0           59.0
# 19         20      Vijay         NaN         79.0           82.0
# 20         21      Sonia       Sagar         78.0           81.0
# 21         22    William     Phillip         85.0           88.0
# 22         23    Michael       Milly         95.0           98.0
# 23         24        NaN        Oven          NaN           90.0
# 24         25     Sandra       Kevin         72.0           75.0
# 25         26       Ryan      Vincia         75.0           78.0
# 26         27        Sam         NaN         85.0           88.0
# 27         28        Vin       Milly         79.0           82.0
# 28         29       Adam        Oven         78.0           81.0
# 29         30       Dana       Kevin         85.0           88.0
# 30         31     Harvey       Milly         95.0           98.0
# 31         32     Norway        Oven         72.0           75.0
# 32         33        NaN         NaN          NaN            3.0
# 33         34      Vince      Vincia         86.0           89.0
# 34         35      Roman        Mark         79.0           82.0
# 35         36      Wayne       Milly         78.0           81.0
# 36         37       Ajay        Oven         85.0           88.0
# 37         38      Vijay       Kevin         95.0           98.0
# 38         39        NaN         NaN          NaN            NaN
# 39         40     Pankaj       Milly         79.0           82.0
# 40         41    Shubham        Oven         78.0           81.0
# 41         42    Shubhra       Kevin         85.0           88.0
# 42         43      Vikas       Sagar         95.0           98.0
# 43         44     Mayank     Phillip         81.0           84.0
#
#     english_marks  history_marks  sports_marks  gross_marks  mentor_rating  \
# 0            77.0           94.0          87.0        401.0            7.0
# 1            90.0           81.0          79.0        401.0            8.0
# 2            80.0           87.0          86.0        430.0            9.0
# 3            94.0           79.0          87.0        417.0            7.0
# 4            81.0           86.0          82.0        434.0            7.0
# 5            87.0           87.0          90.0        333.0            8.0
# 6             NaN            NaN           NaN         84.0            8.0
# 7            76.0           90.0          88.0        319.0            6.0
# 8            83.0           81.0          98.0        431.0            9.0
# 9            84.0           88.0          75.0        418.0            9.0
# 10           79.0           98.0          81.0        419.0            8.0
# 11            NaN            NaN           NaN          NaN            NaN
# 12           78.0           81.0          98.0        416.0            6.0
# 13           85.0           88.0          90.0        436.0            9.0
# 14           95.0           98.0          75.0        461.0            6.0
# 15           72.0           90.0          78.0        387.0            9.0
# 16            NaN            NaN           NaN          NaN            8.0
# 17           74.0           78.0          79.0        382.0            8.0
# 18           77.0           88.0          78.0        225.0            6.0
# 19           79.0           79.0          85.0        404.0            9.0
# 20           82.0           78.0          95.0        414.0            9.0
# 21           81.0           85.0          90.0        339.0            8.0
# 22           88.0           95.0          72.0        448.0            9.0
# 23           98.0            NaN           NaN        188.0            7.0
# 24           80.0           72.0          72.0        371.0            7.0
# 25           82.0           75.0          75.0        385.0            8.0
# 26           81.0           85.0          85.0        424.0            8.0
# 27           88.0           79.0          79.0        407.0            6.0
# 28           78.0           78.0          78.0        393.0            9.0
# 29           85.0           85.0          85.0        428.0            9.0
# 30           95.0           95.0          95.0        478.0            8.0
# 31           72.0           72.0          72.0        363.0            9.0
# 32            NaN            NaN           NaN          3.0            7.0
# 33           88.0           86.0          86.0        435.0            8.0
# 34           98.0           79.0          79.0        417.0            8.0
# 35           90.0           78.0          78.0        405.0            6.0
# 36           75.0           85.0          88.0        421.0            9.0
# 37           78.0           95.0          78.0        444.0            9.0
# 38            NaN            NaN           NaN          NaN            NaN
# 39           82.0           79.0          95.0        417.0            9.0
# 40           81.0           78.0          72.0        390.0            7.0
# 41           88.0           85.0          90.0        346.0            6.0
# 42           98.0           95.0          88.0        474.0            9.0
# 43           84.0           81.0          98.0        428.0            9.0
#
#    language  age_yrs  height_cm   country       hobbies
# 0   English     15.0      142.0       USA    Basketball
# 1   English     14.0      143.0       USA       Singing
# 2   English     17.0      144.0       USA        Movies
# 3   English     18.0      137.0       USA           NaN
# 4       NaN     17.0      133.0       USA     Badminton
# 5       NaN     18.0      140.0       USA         Novel
# 6       NaN     16.0        NaN       NaN           NaN
# 7   English     17.0      155.0       USA      Handball
# 8   English     18.0      156.0    Canada     Badminton
# 9     Hindi     15.0      161.0     India         Novel
# 10  English     16.0      159.0       USA         Music
# 11      NaN      NaN        NaN       NaN           NaN
# 12    Hindi     18.0      159.0     India           NaN
# 13  English     17.0      138.0       USA     Badminton
# 14      NaN     18.0      151.0       USA         Novel
# 15      NaN     16.0      155.0       USA         Music
# 16      NaN      NaN        NaN       USA           NaN
# 17  English     18.0      161.0       USA           NaN
# 18  English     17.0      161.0       USA         Novel
# 19    Hindi     18.0      159.0     India      Handball
# 20    Hindi     16.0      148.0     India     Badminton
# 21  English     14.0      151.0       USA  Table Tennis
# 22  English     17.0      155.0       USA  Table Tennis
# 23  English      NaN        NaN       NaN           NaN
# 24      NaN     17.0      145.0       USA  Table Tennis
# 25      NaN     18.0      155.0       USA      Chatting
# 26  English     16.0      156.0    Canada      Handball
# 27  English     17.0      161.0       USA     Badminton
# 28  English     18.0      159.0       USA         Novel
# 29  English     18.0      171.0       USA      Handball
# 30  English     17.0      159.0       USA     Badminton
# 31  English     18.0      148.0       USA  Table Tennis
# 32  English      NaN      155.0    Canada           NaN
# 33  English     14.0      156.0  Auckland         Novel
# 34  English     17.0      161.0  Auckland  Table Tennis
# 35  English      NaN      159.0  Auckland      Chatting
# 36    Hindi     17.0      171.0     India      Handball
# 37    Hindi     18.0      159.0     India     Badminton
# 38      NaN      NaN        NaN       NaN           NaN
# 39    Hindi     17.0      159.0     India      Chatting
# 40    Hindi     18.0        NaN     India      Handball
# 41    Hindi     17.0      148.0     India     Badminton
# 42    Hindi      NaN      159.0     India         Novel
# 43    Hindi     17.0      171.0     India      Handball

# %% [markdown]
# ## Inspect the dataframe

# %%
# Check the dataframe head = first 5 rows
student.head(5)
# Out:
#    serial_no Student mentor_name  maths_marks  science_marks  english_marks  \
# 0          1     Ola       Sagar         70.0           73.0           77.0
# 1          2    Ruby     Phillip         74.0           77.0           90.0
# 2          3   Aimee      Vincia         87.0           90.0           80.0
# 3          4  Olivia        Mark         77.0           80.0           94.0
# 4          5    Otis       Milly         91.0           94.0           81.0
#
#    history_marks  sports_marks  gross_marks  mentor_rating language  age_yrs  \
# 0           94.0          87.0        401.0            7.0  English     15.0
# 1           81.0          79.0        401.0            8.0  English     14.0
# 2           87.0          86.0        430.0            9.0  English     17.0
# 3           79.0          87.0        417.0            7.0  English     18.0
# 4           86.0          82.0        434.0            7.0      NaN     17.0
#
#    height_cm country     hobbies
# 0      142.0     USA  Basketball
# 1      143.0     USA     Singing
# 2      144.0     USA      Movies
# 3      137.0     USA         NaN
# 4      133.0     USA   Badminton

# %%
# Check the dataframe tail = last 5 rows
student.tail(5)
# Out:
#     serial_no  Student mentor_name  maths_marks  science_marks  english_marks  \
# 39         40   Pankaj       Milly         79.0           82.0           82.0
# 40         41  Shubham        Oven         78.0           81.0           81.0
# 41         42  Shubhra       Kevin         85.0           88.0           88.0
# 42         43    Vikas       Sagar         95.0           98.0           98.0
# 43         44   Mayank     Phillip         81.0           84.0           84.0
#
#     history_marks  sports_marks  gross_marks  mentor_rating language  age_yrs  \
# 39           79.0          95.0        417.0            9.0    Hindi     17.0
# 40           78.0          72.0        390.0            7.0    Hindi     18.0
# 41           85.0          90.0        346.0            6.0    Hindi     17.0
# 42           95.0          88.0        474.0            9.0    Hindi      NaN
# 43           81.0          98.0        428.0            9.0    Hindi     17.0
#
#     height_cm country    hobbies
# 39      159.0   India   Chatting
# 40        NaN   India   Handball
# 41      148.0   India  Badminton
# 42      159.0   India      Novel
# 43      171.0   India   Handball

# %%
# Check the dataframe information
print(student.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 15 columns):
# serial_no        44 non-null int64
# Student          38 non-null object
# mentor_name      38 non-null object
# maths_marks      39 non-null float64
# science_marks    40 non-null float64
# english_marks    39 non-null float64
# history_marks    38 non-null float64
# sports_marks     38 non-null float64
# gross_marks      41 non-null float64
# mentor_rating    42 non-null float64
# language         34 non-null object
# age_yrs          37 non-null float64
# height_cm        38 non-null float64
# country          40 non-null object
# hobbies          35 non-null object
# dtypes: float64(9), int64(1), object(5)
# memory usage: 5.3+ KB
# None

# %%
# Check the dataframe description
print(student.describe())
# Out:
#        serial_no  maths_marks  science_marks  english_marks  history_marks  \
# count  44.000000    39.000000      40.000000      39.000000      38.000000
# mean   22.500000    81.641026      82.125000      83.666667      84.552632
# std    12.845233     7.005589      15.144073       7.150021       7.023887
# min     1.000000    70.000000       3.000000      72.000000      72.000000
# 25%    11.750000    78.000000      79.750000      78.500000      79.000000
# 50%    22.500000    79.000000      82.000000      82.000000      85.000000
# 75%    33.250000    85.000000      88.000000      88.000000      88.000000
# max    44.000000    95.000000      98.000000      98.000000      98.000000
#
#        sports_marks  gross_marks  mentor_rating    age_yrs   height_cm
# count     38.000000    41.000000      42.000000  37.000000   38.000000
# mean      83.842105   380.878049       7.880952  16.864865  154.210526
# std        7.855197    95.987810       1.108776   1.205593    9.162668
# min       72.000000     3.000000       6.000000  14.000000  133.000000
# 25%       78.000000   382.000000       7.000000  16.000000  148.000000
# 50%       85.000000   414.000000       8.000000  17.000000  156.000000
# 75%       89.500000   428.000000       9.000000  18.000000  159.000000
# max       98.000000   478.000000       9.000000  18.000000  171.000000

# %%
print(student.shape)
# Out:
# (44, 15)

# %% [markdown]
# ## Data Cleaning

# %%
# Check for column-wise null count 
student.isnull().sum()
# Out:
# serial_no         0
# Student           6
# mentor_name       6
# maths_marks       5
# science_marks     4
# english_marks     5
# history_marks     6
# sports_marks      6
# gross_marks       3
# mentor_rating     2
# language         10
# age_yrs           7
# height_cm         6
# country           4
# hobbies           9
# dtype: int64

# %%
# Check for row-wise null count 
student.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1
# 6      9
# 7      0
# 8      0
# 9      0
# 10     0
# 11    14
# 12     1
# 13     0
# 14     1
# 15     1
# 16    11
# 17     1
# 18     1
# 19     1
# 20     0
# 21     0
# 22     0
# 23     8
# 24     1
# 25     1
# 26     1
# 27     0
# 28     0
# 29     0
# 30     0
# 31     0
# 32     8
# 33     0
# 34     0
# 35     1
# 36     0
# 37     0
# 38    14
# 39     0
# 40     1
# 41     0
# 42     1
# 43     0
# dtype: int64

# %%
# Check for column-wise null percentages
round(100*(student.isnull().sum()/len(student.index)), 2)
# Out:
# serial_no         0.00
# Student          13.64
# mentor_name      13.64
# maths_marks      11.36
# science_marks     9.09
# english_marks    11.36
# history_marks    13.64
# sports_marks     13.64
# gross_marks       6.82
# mentor_rating     4.55
# language         22.73
# age_yrs          15.91
# height_cm        13.64
# country           9.09
# hobbies          20.45
# dtype: float64

# %%
# Drop unneccessary columns
student = student.drop('serial_no', axis=1)
student = student.drop('hobbies', axis=1)
student = student.drop('mentor_name', axis=1)

# Check for column-wise null percentages again post dropping unnecessary columns
round(100*(student.isnull().sum()/len(student.index)), 2)
# Out:
# Student          13.64
# maths_marks      11.36
# science_marks     9.09
# english_marks    11.36
# history_marks    13.64
# sports_marks     13.64
# gross_marks       6.82
# mentor_rating     4.55
# language         22.73
# age_yrs          15.91
# height_cm        13.64
# country           9.09
# dtype: float64

# %% [markdown]
# ### Now, on inspection you might notice that some columns have large percentage of Null values. Drop all the rows which have Null values for such columns.

# %%
# Drop rows with high % of null values in columns with high null value %
student = student[~np.isnan(student['sports_marks'])]

# Check for column-wise null percentages again post dropping unnecessary rows
round(100*(student.isnull().sum()/len(student.index)), 2)
# Out:
# Student           0.00
# maths_marks       0.00
# science_marks     0.00
# english_marks     0.00
# history_marks     0.00
# sports_marks      0.00
# gross_marks       0.00
# mentor_rating     0.00
# language         15.79
# age_yrs           5.26
# height_cm         2.63
# country           0.00
# dtype: float64

# %%
# count the number of rows having > 5 missing values
len(student[student.isnull().sum(axis=1) >= 2].index)
# Out:
# 0

# %%
# Write your code for dropping the rows with more than 3 null values here
student = student[student.isnull().sum(axis=1) <= 2]

# Check for column-wise null percentages again post dropping unnecessary rows
round(100*(student.isnull().sum()/len(student.index)), 2)
# Out:
# Student           0.00
# maths_marks       0.00
# science_marks     0.00
# english_marks     0.00
# history_marks     0.00
# sports_marks      0.00
# gross_marks       0.00
# mentor_rating     0.00
# language         15.79
# age_yrs           5.26
# height_cm         2.63
# country           0.00
# dtype: float64

# %%
# Inspect the language column
student['language'].describe()
# Out:
# count          32
# unique          2
# top       English
# freq           21
# Name: language, dtype: object

# %%
# fill the NaN values in the 'language' column here
student["language"].fillna("English", inplace = True) 

# Check for column-wise null percentages again post dropping unnecessary rows
round(100*(student.isnull().sum()/len(student.index)), 2)
# Out:
# Student          0.00
# maths_marks      0.00
# science_marks    0.00
# english_marks    0.00
# history_marks    0.00
# sports_marks     0.00
# gross_marks      0.00
# mentor_rating    0.00
# language         0.00
# age_yrs          5.26
# height_cm        2.63
# country          0.00
# dtype: float64

# %%
# Write your code for checking number of retained rows here
print(student.shape)
# Out:
# (38, 12)

# %%
# Check the % of rows left
len(student.index)/5043 # Check the % of rows left
# Out:
# 0.007535197303192544
